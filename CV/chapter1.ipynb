# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img0 = np.array([
    [0,0,1],
    [0,1,0],
    [1,0,0]
])

# %%
# plt.imshow(img0)
# plt.imshow(img0, cmap="binary")abc
plt.imshow(img0, cmap="gray")

# %%
import cv2

# %%
img = cv2.imread('lena.jpg')
img =

# %%
print(img.shape)
# Out:
# (722, 726, 3)

# %%
plt.imshow(img)

# %%
# region of instrest
roi = img[200:400, 400:600]

# %%
plt.imshow(roi)

# %%
cap = cv2.VideoCapture(0)

# %%
return_value, frame = cap.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
cap.release()
