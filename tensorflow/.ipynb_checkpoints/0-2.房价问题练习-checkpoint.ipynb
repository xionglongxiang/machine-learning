# %% [markdown]
# ## 房价问题练习

# %% [markdown]
# 在本次练习中，你将尝试构建神经网络来预测房屋的价格。
#
# 首先，将房价的计算想象的简单一点，假设：
# 1居室 100k
# 2居室 150k
# 3居室 200k
# ...
# 每增加一居室就增加50k。
#
# 你将创建一个神经网络，以便预测7居室的价格接近 400k。

# %% [markdown]
# 依旧导入tensorflow、numpy

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# 定义一个 模型函数
def house_model(y_new):
    # 准备数据
    # 定义模型
    # 编译
    # 训练
    # 返回预测的结果
    return model.predict(y_new)[0]

# %%
prediction = house_model([7.0])
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 896us/step - loss: 61168.9492
# Epoch 2/500
# 1/1 [==============================] - 0s 488us/step - loss: 28442.6582
# Epoch 3/500
# 1/1 [==============================] - 0s 642us/step - loss: 13294.9932
# Epoch 4/500
# 1/1 [==============================] - 0s 627us/step - loss: 6283.2446
# Epoch 5/500
# 1/1 [==============================] - 0s 596us/step - loss: 3037.0496
# Epoch 6/500
# 1/1 [==============================] - 0s 580us/step - loss: 1533.6738
# Epoch 7/500
# 1/1 [==============================] - 0s 898us/step - loss: 836.9335
# Epoch 8/500
# 1/1 [==============================] - 0s 609us/step - loss: 513.5348
# Epoch 9/500
# 1/1 [==============================] - 0s 877us/step - loss: 362.9376
# Epoch 10/500
# 1/1 [==============================] - 0s 645us/step - loss: 292.3239
# Epoch 11/500
# 1/1 [==============================] - 0s 655us/step - loss: 258.7357
# Epoch 12/500
# ...

# %%
print(prediction)
# Out:
# [403.67017]
