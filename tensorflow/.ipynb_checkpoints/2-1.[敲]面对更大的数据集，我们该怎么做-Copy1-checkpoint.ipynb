# %% [markdown]
# ## 训练一个猫狗分类器
#
# 你已经学习了如何使用 CNN 来识别手写数字。手写数字识别的图像大小和形状都是一样的，而且是灰度图像。
#
# 现在，我们来做一个更有难度的！
#
# 我们来一起[打个比赛](https://www.kaggle.com/c/dogs-vs-cats)！

# %% [markdown]
# ### 探索示例数据
#
# 数据集下载： http://aimaksen.bslience.cn/cats_and_dogs_filtered.zip
#
# 将 cats_and_dogs_filtered.zip 解压。文件包含训练集和验证集。训练集中包含猫和狗的子目录。

# %%
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# 我们看看猫和狗训练目录中的文件名是什么样的！

# %%
# Out:
# ['cat.47.jpg', 'cat.959.jpg', 'cat.29.jpg', 'cat.429.jpg', 'cat.636.jpg', 'cat.1.jpg', 'cat.419.jpg', 'cat.977.jpg', 'cat.535.jpg', 'cat.499.jpg']
# ['dog.683.jpg', 'dog.724.jpg', 'dog.160.jpg', 'dog.547.jpg', 'dog.406.jpg', 'dog.508.jpg', 'dog.738.jpg', 'dog.908.jpg', 'dog.866.jpg', 'dog.625.jpg']

# %% [markdown]
# 查看训练和验证目录中猫和狗图像的总数：

# %%
# Out:
# total training cat images : 1000
# total training dog images : 1000
# total validation cat images : 500
# total validation dog images : 500

# %% [markdown]
# 再来看看猫和狗的图片都长什么样子！配置 matplotlib 参数

# %% [markdown]
# 查看8只猫和8只狗的图片(另一种画图的方法)

# %% [markdown]
# 观察上述图片。
#
# 本次使用的数据集与手写数字识别数据集有一个显著的区别：现在的图像不是相同大小。
#
# 现在，你知道图片长什么样子了，现在开始制作分类器吧！

# %% [markdown]
# ### 搭建 baseline
#
# 步骤一 导入 tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# 步骤二 搭建模型

# %% [markdown]
# 打印神经网络的层

# %%
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9470464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 步骤三 编译

# %% [markdown]
# 步骤四 数据处理
#
# 依旧使用 keras.preprocessing.image.ImageDataGenerator 类

# %%
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# 步骤五 训练

# %%
# Out:
# Epoch 1/15
# 100/100 [==============================] - 10s 92ms/step - loss: 1.0050 - accuracy: 0.5650 - val_loss: 0.6686 - val_accuracy: 0.6770
# Epoch 2/15
# 100/100 [==============================] - 9s 86ms/step - loss: 0.6529 - accuracy: 0.6530 - val_loss: 0.6007 - val_accuracy: 0.6610
# Epoch 3/15
# 100/100 [==============================] - 8s 84ms/step - loss: 0.5664 - accuracy: 0.7255 - val_loss: 0.5738 - val_accuracy: 0.7270
# Epoch 4/15
# 100/100 [==============================] - 8s 83ms/step - loss: 0.4372 - accuracy: 0.7870 - val_loss: 0.5960 - val_accuracy: 0.7060
# Epoch 5/15
# 100/100 [==============================] - 9s 86ms/step - loss: 0.3386 - accuracy: 0.8485 - val_loss: 0.6344 - val_accuracy: 0.7220
# Epoch 6/15
# 100/100 [==============================] - 9s 85ms/step - loss: 0.2316 - accuracy: 0.9010 - val_loss: 0.8818 - val_accuracy: 0.7220
# Epoch 7/15
# 100/100 [==============================] - 8s 85ms/step - loss: 0.1580 - accuracy: 0.9360 - val_loss: 0.9719 - val_accuracy: 0.7050
# Epoch 8/15
# 100/100 [==============================] - 9s 86ms/step - loss: 0.1023 - accuracy: 0.9675 - val_loss: 1.0801 - val_accuracy: 0.7110
# Epoch 9/15
# 100/100 [==============================] - 8s 83ms/step - loss: 0.1473 - accuracy: 0.9785 - val_loss: 1.5084 - val_accuracy: 0.6940
# Epoch 10/15
# 100/100 [==============================] - 9s 85ms/step - loss: 0.0541 - accuracy: 0.9845 - val_loss: 2.5326 - val_accuracy: 0.6600
# Epoch 11/15
# 100/100 [==============================] - 8s 83ms/step - loss: 0.1051 - accuracy: 0.9790 - val_loss: 1.5702 - val_accuracy: 0.6890
# Epoch 12/15
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0441 - accuracy: 0.9895 - val_loss: 2.0318 - val_accuracy: 0.7110
# Epoch 13/15
# 100/100 [==============================] - 9s 85ms/step - loss: 0.0262 - accuracy: 0.9920 - val_loss: 2.0624 - val_accuracy: 0.7020
# Epoch 14/15
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0353 - accuracy: 0.9895 - val_loss: 2.6189 - val_accuracy: 0.6970
# Epoch 15/15
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0515 - accuracy: 0.9920 - val_loss: 2.2935 - val_accuracy: 0.7260

# %% [markdown]
# 步骤六 预测

# %%
# Out:
# [0.00011539]
# it is a cat.jpeg

# %% [markdown]
# ### 可视化卷积神经网络

# %%
# Out:
#       <iframe id="tensorboard-frame-5986c01acc293e9d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5986c01acc293e9d");
#           const url = new URL("/", window.location);
#           const port = 6123;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ## VGG 16
#
# ![](https://www.researchgate.net/profile/Max-Ferguson/publication/322512435/figure/fig3/AS:697390994567179@1543282378794/Fig-A1-The-standard-VGG-16-network-architecture-as-proposed-in-32-Note-that-only.png)

# %%
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 220, 220, 32)      9248
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 108, 108, 64)      18496
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 106, 106, 64)      36928
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 53, 53, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 51, 51, 128)       73856
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 49, 49, 128)       147584
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 24, 24, 128)       0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 73728)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               37749248
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 38,036,769
# Trainable params: 38,036,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 100/100 [==============================] - 10s 91ms/step - loss: 0.7083 - accuracy: 0.4840 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 2/40
# 100/100 [==============================] - 8s 82ms/step - loss: 0.7005 - accuracy: 0.5065 - val_loss: 0.6959 - val_accuracy: 0.5000
# Epoch 3/40
# 100/100 [==============================] - 8s 81ms/step - loss: 0.7017 - accuracy: 0.4840 - val_loss: 0.6918 - val_accuracy: 0.5680
# Epoch 4/40
# 100/100 [==============================] - 8s 82ms/step - loss: 0.7215 - accuracy: 0.5000 - val_loss: 0.6921 - val_accuracy: 0.5000
# Epoch 5/40
# 100/100 [==============================] - 8s 82ms/step - loss: 0.6950 - accuracy: 0.5370 - val_loss: 0.6759 - val_accuracy: 0.6300
# Epoch 6/40
#  66/100 [==================>...........] - ETA: 1s - loss: 0.7188 - accuracy: 0.5682
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-a0924e342224> in <module>
#      45     validation_steps=50,
#      46     verbose=1,
# ---> 47     callbacks=[tensorboard_callback],
#      48 )
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# 为什么说 Dropout 可以解决过拟合？
#
#
#
# - （1）取平均的作用： 先回到标准的模型即没有dropout，我们用相同的训练数据去训练5个不同的神经网络，一般会得到5个不同的结果，此时我们可以采用 “5个结果取均值”或者“多数取胜的投票策略”去决定最终结果。例如3个网络判断结果为数字9,那么很有可能真正的结果就是数字9，其它两个网络给出了错误结果。这种“综合起来取平均”的策略通常可以有效防止过拟合问题。因为不同的网络可能产生不同的过拟合，取平均则有可能让一些“相反的”拟合互相抵消。dropout掉不同的隐藏神经元就类似在训练不同的网络，随机删掉一半隐藏神经元导致网络结构已经不同，整个dropout过程就相当于对很多个不同的神经网络取平均。而不同的网络产生不同的过拟合，一些互为“反向”的拟合相互抵消就可以达到整体上减少过拟合。
#
# - （2）减少神经元之间复杂的共适应关系： 因为dropout程序导致两个神经元不一定每次都在一个dropout网络中出现。这样权值的更新不再依赖于有固定关系的隐含节点的共同作用，阻止了某些特征仅仅在其它特定特征下才有效果的情况 。迫使网络去学习更加鲁棒的特征 ，这些特征在其它的神经元的随机子集中也存在。换句话说假如我们的神经网络是在做出某种预测，它不应该对一些特定的线索片段太过敏感，即使丢失特定的线索，它也应该可以从众多其它线索中学习一些共同的特征。从这个角度看dropout就有点像L1，L2正则，减少权重使得网络对丢失特定神经元连接的鲁棒性提高。
#
# - （3）Dropout类似于性别在生物进化中的角色：物种为了生存往往会倾向于适应这种环境，环境突变则会导致物种难以做出及时反应，性别的出现可以繁衍出适应新环境的变种，有效的阻止过拟合，即避免环境改变时物种可能面临的灭绝。

# %% [markdown]
# ## 数据增强
#
# [接口文档](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomFlip)

# %%
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_5 (Sequential)    (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 220, 220, 32)      9248
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 108, 108, 64)      18496
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 106, 106, 64)      36928
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 53, 53, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 51, 51, 128)       73856
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 49, 49, 128)       147584
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 24, 24, 128)       0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 73728)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               37749248
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 38,036,769
# Trainable params: 38,036,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 100/100 [==============================] - 10s 95ms/step - loss: 0.9683 - accuracy: 0.4865 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 2/100
# 100/100 [==============================] - 8s 85ms/step - loss: 0.7029 - accuracy: 0.4855 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 3/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.6959 - accuracy: 0.4995 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 4/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.7061 - accuracy: 0.5175 - val_loss: 0.6819 - val_accuracy: 0.5530
# Epoch 5/100
# 100/100 [==============================] - 9s 86ms/step - loss: 0.6917 - accuracy: 0.5375 - val_loss: 0.6646 - val_accuracy: 0.5790
# Epoch 6/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.7093 - accuracy: 0.5595 - val_loss: 0.6736 - val_accuracy: 0.5580
# Epoch 7/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.6932 - accuracy: 0.5725 - val_loss: 0.6729 - val_accuracy: 0.5990
# Epoch 8/100
# 100/100 [==============================] - 9s 85ms/step - loss: 0.6710 - accuracy: 0.6010 - val_loss: 0.6738 - val_accuracy: 0.5100
# Epoch 9/100
# 100/100 [==============================] - 9s 87ms/step - loss: 0.6902 - accuracy: 0.6185 - val_loss: 0.6396 - val_accuracy: 0.6270
# Epoch 10/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.6473 - accuracy: 0.6240 - val_loss: 0.6267 - val_accuracy: 0.6460
# Epoch 11/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.6478 - accuracy: 0.6400 - val_loss: 0.6316 - val_accuracy: 0.6340
# Epoch 12/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.6522 - accuracy: 0.6420 - val_loss: 0.6039 - val_accuracy: 0.6790
# Epoch 13/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.6269 - accuracy: 0.6570 - val_loss: 0.6658 - val_accuracy: 0.6650
# Epoch 14/100
# 100/100 [==============================] - 9s 87ms/step - loss: 0.6481 - accuracy: 0.6615 - val_loss: 0.6116 - val_accuracy: 0.6770
# Epoch 15/100
# 100/100 [==============================] - 8s 83ms/step - loss: 0.6127 - accuracy: 0.6745 - val_loss: 0.5860 - val_accuracy: 0.6800
# Epoch 16/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.6140 - accuracy: 0.6720 - val_loss: 0.6501 - val_accuracy: 0.6420
# Epoch 17/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.6057 - accuracy: 0.6945 - val_loss: 0.5952 - val_accuracy: 0.6890
# Epoch 18/100
# 100/100 [==============================] - 9s 86ms/step - loss: 0.6184 - accuracy: 0.6680 - val_loss: 0.5771 - val_accuracy: 0.7030
# Epoch 19/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.5955 - accuracy: 0.6865 - val_loss: 0.5815 - val_accuracy: 0.6920
# Epoch 20/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.5793 - accuracy: 0.7000 - val_loss: 0.5399 - val_accuracy: 0.7060
# Epoch 21/100
# 100/100 [==============================] - 8s 81ms/step - loss: 0.5980 - accuracy: 0.7010 - val_loss: 0.6036 - val_accuracy: 0.7010
# Epoch 22/100
# 100/100 [==============================] - 9s 87ms/step - loss: 0.5938 - accuracy: 0.6990 - val_loss: 0.5616 - val_accuracy: 0.7140
# Epoch 23/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.5784 - accuracy: 0.7070 - val_loss: 0.5884 - val_accuracy: 0.6990
# Epoch 24/100
# 100/100 [==============================] - 9s 85ms/step - loss: 0.5874 - accuracy: 0.7010 - val_loss: 0.5470 - val_accuracy: 0.7310
# Epoch 25/100
# 100/100 [==============================] - 8s 82ms/step - loss: 0