# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.6.0'

# %%
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.experimental.set_visible_devices(devices=gpus[0], device_type="GPU")

# %%
# train_path_to_file = tf.keras.utils.get_file(
#     'train.zip',
#     cache_subdir='cats_and_dogs',
#     origin='https://storage.googleapis.com/kagglesdsdata/competitions/5441/38425/train.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1641736738&Signature=QeHMz9Yr0jv11t8oP8eBTj%2FxZsj%2BxSSkfj65k5d0FzNv2d9Vt5lGs9JITcyZoawm6Tc8guUnkEq58qjDNyxi7%2Fg6wRSgctnZ6oHFRx6F7liEtlQb%2F1FnhAOkrxqLIgbu9%2FmVKoXLnk02Dqj9Hc0BBeSyV3P5svKbn4%2FFCWoWaTjgY9oqS1IIUDUhOy71t%2FuX1EEbH2%2FwquCEG%2F3OM3zK3lrQbf1O3uAC3R%2Bka%2F28mYrUGPKZf4GdRH8e%2BA%2Bv0Ky5NhRUclGMfN6LdvrSgy9%2BZIaBeZFxKEvKkTBSLcfynungAKN4%2Bi5mwgCctBR7J26mlHlP6vWKR2ET7yZ16QM12w%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain.zip',
#     extract=True
# )

# %%
# test_path_to_file = tf.keras.utils.get_file(
#     'test.zip',
#     cache_subdir='cats_and_dogs',
#     origin='https://storage.googleapis.com/kagglesdsdata/competitions/5441/38425/test.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1641736717&Signature=eyHTxDC8vvViWjKrU4mCqZxhs92l%2BNhgxpoAME0TaW8cOApu4Ax2QKgecLT7EcL9fOVzMZfDhthwMY1yiWNddldh5cOSrtjo9saIifwDagwEop9l5yuEaem3r5gEeh%2FkD4Cg4s%2BMH6LbHHPKy6461h4v7N3RQ4HLBC0ntKwhsjm0iECSbZir1rUZLBGenPOZodRA5hBu1V3qXu%2FRDLybrXau45jv%2Fg8cQaufAr5X0gzPoL8F%2Fz7TW4owC6w69dXkcGuE3q1uaO7mgz4dQC8c9wlPryNXvnrZZ6RSz43pR%2BuVBmUY30AKIr5UaavANy%2F9BH0pBXnwWdUelSB7CkLBfA%3D%3D&response-content-disposition=attachment%3B+filename%3Dtest.zip',
#     extract=True
# )

# %%
# import pathlib
# pathlib.Path(train_path_to_file).parent

# %%
train_dir = 'C:/Users/Administrator/.keras/cats_and_dogs/train'
test_dir = 'C:/Users/Administrator/.keras/cats_and_dogs/test'

# %%
import os

# %%
train_dogs_dir = os.path.join(train_dir, 'dogs')
if not os.path.exists(train_dogs_dir):
    os.mkdir(train_dogs_dir)

os.path.exists(train_dogs_dir)
# Out:
# True

# %%
train_cats_dir = os.path.join(train_dir, 'cats')
if not os.path.exists(train_cats_dir):
    os.mkdir(train_cats_dir)

os.path.exists(train_cats_dir)
# Out:
# True

# %%
len(os.listdir(train_cats_dir))
# Out:
# 12500

# %%
import re
import shutil

train_name_list = os.listdir(train_dir)

for i in range(len(train_name_list)):
    path = os.path.join(train_dir,train_name_list[i])
    if re.search('cat', train_name_list[i]):
        shutil.move(path, train_cats_dir)
    if re.search('dog', train_name_list[i]):
        shutil.move(path, train_dogs_dir)

# %%
len(os.listdir(train_dogs_dir))
# Out:
# 12500

# %%
len(os.listdir(train_cats_dir))
# Out:
# 12500

# %%
train_dogs_name_list = os.listdir(train_dogs_dir)
len(train_dogs_name_list)
# Out:
# 12500

# %%
train_cats_name_list = os.listdir(train_cats_dir)
len(train_cats_name_list)
# Out:
# 12500

# %%
# import PIL
# import matplotlib.pyplot as plt

# cats_filepath = train_cats_dir
# fig = plt.figure(1, figsize=(20,20))

# for i in range(10):
#     plt.subplot(5, 5, i + 1)
#     pic = PIL.Image.open(os.path.join(train_dogs_dir, train_dogs_name_list[i]))
#     plt.imshow(pic)
#     plt.axis('off')
# plt.show()

# %%
# import PIL
# import matplotlib.pyplot as plt

# cats_filepath = train_cats_dir
# fig = plt.figure(1, figsize=(20,20))

# for i in range(10):
#     plt.subplot(5, 5, i + 1)
#     pic = PIL.Image.open(os.path.join(train_cats_dir, train_cats_name_list[i]))
#     plt.imshow(pic)
#     plt.axis('off')
# plt.show()

# %%
img_height = 224
img_width = 224
batch_size = 32

from  tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/225)
rotation_range=l_datagen = ImageDataGenerator(rescale=1/255)

train_gen = ImageDataGenerator(rescale=1 / 255.0, validation_split=0.2)

train_generator = train_gen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="binary",
    subset="training",
)

val_generator = train_gen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="binary",
    subset="validation",
)

data_augumentation_layer=tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal", input_shape=(224,224, 3)),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1)
])

model = tf.keras.models.Sequential(
    [
        data_augumentation_layer,
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation='sigmoid')

    ]
)
model.summary()

from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=['accuracy']

)

from datetime import datetime

logdir = 'logs/fit/' + datetime.now().strftime("%Y%m%d-%H%M%S") + "baseline"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    steps_per_epoch=100,
    epochs=100,
    validation_steps=50,
    verbose=1,
    callbacks=[tensorboard_callback]
)

# %%
img_height = 224
img_width = 224
batch_size = 32

from  tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/225)
rotation_range=l_datagen = ImageDataGenerator(rescale=1/255)

train_gen = ImageDataGenerator(rescale=1 / 255.0, validation_split=0.2)

train_generator = train_gen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="binary",
    subset="training",
)

val_generator = train_gen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="binary",
    subset="validation",
)

data_augumentation_layer=tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal", input_shape=(224,224, 3)),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1)
])

model = tf.keras.models.Sequential(
    [
        data_augumentation_layer,
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation='sigmoid')

    ]
)
model.summary()

from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=['accuracy']

)

from datetime import datetime

logdir = 'logs/fit/' + datetime.now().strftime("%Y%m%d-%H%M%S") + "baseline"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    steps_per_epoch=100,
    epochs=100,
    validation_steps=50,
    verbose=1,
    callbacks=[tensorboard_callback]
)
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_18 (Sequential)   (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 220, 220, 32)      9248
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 108, 108, 64)      18496
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 106, 106, 64)      36928
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 53, 53, 64)        0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 51, 51, 128)       73856
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 49, 49, 128)       147584
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 24, 24, 128)       0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 73728)             0
# _________________________________________________________________
# dense_19 (Dense)             (None, 512)               37749248
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 38,036,769
# Trainable params: 38,036,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 100/100 [==============================] - 14s 126ms/step - loss: 0.8367 - accuracy: 0.5013 - val_loss: 0.6909 - val_accuracy: 0.5813
# Epoch 2/100
# 100/100 [==============================] - 12s 116ms/step - loss: 0.7480 - accuracy: 0.5238 - val_loss: 0.6633 - val_accuracy: 0.6413
# Epoch 3/100
# 100/100 [==============================] - 12s 117ms/step - loss: 0.7148 - accuracy: 0.5797 - val_loss: 0.6730 - val_accuracy: 0.5850
# Epoch 4/100
# 100/100 [==============================] - 12s 118ms/step - loss: 0.7208 - accuracy: 0.6062 - val_loss: 0.6618 - val_accuracy: 0.6481
# Epoch 5/100
# 100/100 [==============================] - 12s 120ms/step - loss: 0.6720 - accuracy: 0.6137 - val_loss: 0.6523 - val_accuracy: 0.6263
# Epoch 6/100
# 100/100 [==============================] - 12s 120ms/step - loss: 0.6510 - accuracy: 0.6297 - val_loss: 0.6380 - val_accuracy: 0.6019
# Epoch 7/100
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6396 - accuracy: 0.6469 - val_loss: 0.6227 - val_accuracy: 0.6844
# Epoch 8/100
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6397 - accuracy: 0.6616 - val_loss: 0.5796 - val_accuracy: 0.6988
# Epoch 9/100
# 100/100 [==============================] - 12s 118ms/step - loss: 0.6222 - accuracy: 0.6734 - val_loss: 1.3511 - val_accuracy: 0.5650
# Epoch 10/100
# 100/100 [==============================] - 12s 120ms/step - loss: 0.6301 - accuracy: 0.6612 - val_loss: 0.5728 - val_accuracy: 0.7094
# Epoch 11/100
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4564 - accuracy: 0.8188 - val_loss: 0.3374 - val_accuracy: 0.8413
# Epoch 91/100
# 100/100 [==============================] - 12s 122ms/step - loss: 0.4214 - accuracy: 0.8238 - val_loss: 0.3235 - val_accuracy: 0.8606
# Epoch 92/100
# 100/100 [==============================] - 12s 120ms/step - loss: 0.4831 - accuracy: 0.8188 - val_loss: 0.5929 - val_accuracy: 0.6762
# Epoch 93/100
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4313 - accuracy: 0.8259 - val_loss: 0.3159 - val_accuracy: 0.8788
# Epoch 94/100
# 100/100 [==============================] - 12s 120ms/step - loss: 0.4432 - accuracy: 0.8181 - val_loss: 0.2912 - val_accuracy: 0.8731
# Epoch 95/100
# 100/100 [==============================] - 13s 125ms/step - loss: 0.4436 - accuracy: 0.8275 - val_loss: 0.3644 - val_accuracy: 0.8406
# Epoch 96/100
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4303 - accuracy: 0.8169 - val_loss: 0.9317 - val_accuracy: 0.6562
# Epoch 97/100
# 100/100 [==============================] - 13s 127ms/step - loss: 0.3828 - accuracy: 0.8375 - val_loss: 0.3872 - val_accuracy: 0.8425
# Epoch 98/100
# 100/100 [==============================] - 12s 121ms/step - loss: 0.4139 - accuracy: 0.8213 - val_loss: 1.1343 - val_accuracy: 0.6169
# Epoch 99/100
# 100/100 [==============================] - 13s 129ms/step - loss: 0.5589 - accuracy: 0.7959 - val_loss: 0.3726 - val_accuracy: 0.8394
# Epoch 100/100
# 100/100 [==============================] - 12s 121ms/step - loss: 0.4456 - accuracy: 0.8144 - val_loss: 0.3283 - val_accuracy: 0.8600

# %%
img_height = 224
img_width = 224
batch_size = 32

from  tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/225, rotation_range=40, width_shift_range=0.2, height_shift_range=0.2, zoom_range=0.2, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1/255)

train_gen = ImageDataGenerator(rescale=1 / 255.0, validation_split=0.2)

train_generator = train_gen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="binary",
    subset="training",
)

val_generator = train_gen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="binary",
    subset="validation",
)


model = tf.keras.models.Sequential(
    [
        tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation='sigmoid')

    ]
)
model.summary()

from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=['accuracy']

)

from datetime import datetime

logdir = 'logs/fit/' + datetime.now().strftime("%Y%m%d-%H%M%S") + "baseline"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    steps_per_epoch=100,
    epochs=100,
    validation_steps=50,
    verbose=1,
    callbacks=[tensorboard_callback]
)
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_65 (Conv2D)           (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 220, 220, 32)      9248
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 108, 108, 64)      18496
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 106, 106, 64)      36928
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 53, 53, 64)        0
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 51, 51, 128)       73856
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 49, 49, 128)       147584
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 24, 24, 128)       0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 73728)             0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               37749248
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 38,036,769
# Trainable params: 38,036,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 100/100 [==============================] - 14s 130ms/step - loss: 1.3424 - accuracy: 0.4900 - val_loss: 0.6924 - val_accuracy: 0.4963
# Epoch 2/100
# 100/100 [==============================] - 12s 117ms/step - loss: 0.7318 - accuracy: 0.5291 - val_loss: 0.6816 - val_accuracy: 0.5537
# Epoch 3/100
# 100/100 [==============================] - 13s 125ms/step - loss: 0.6946 - accuracy: 0.5519 - val_loss: 0.6941 - val_accuracy: 0.5325
# Epoch 4/100
# 100/100 [==============================] - 13s 129ms/step - loss: 0.6839 - accuracy: 0.6037 - val_loss: 0.6261 - val_accuracy: 0.6731
# Epoch 5/100
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6449 - accuracy: 0.6428 - val_loss: 0.6846 - val_accuracy: 0.6275
# Epoch 6/100
# 100/100 [==============================] - 12s 118ms/step - loss: 0.6344 - accuracy: 0.6500 - val_loss: 0.6161 - val_accuracy: 0.6519
# Epoch 7/100
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6062 - accuracy: 0.6809 - val_loss: 0.5888 - val_accuracy: 0.6856
# Epoch 8/100
# 100/100 [==============================] - 12s 120ms/step - loss: 0.5824 - accuracy: 0.6934 - val_loss: 0.5705 - val_accuracy: 0.6931
# Epoch 9/100
# 100/100 [==============================] - 12s 122ms/step - loss: 0.5592 - accuracy: 0.7166 - val_loss: 0.6114 - val_accuracy: 0.6806
# Epoch 10/100
# 100/100 [==============================] - 12s 117ms/step - loss: 0.5517 - accuracy: 0.7209 - val_loss: 0.5729 - val_accuracy: 0.7237
# Epoch 11/100
# 100/100 [==============================] - 13s 126ms/step - loss: 0.5444 - accuracy: 0.7387 - val_loss: 0.5217 - val_accuracy: 0.7437
# Epoch 12/100
# 100/100 [==============================] - 12s 118ms/step - loss: 0.5300 - accuracy: 0.7506 - val_loss: 0.5294 - val_accuracy: 0.7381
# Epoch 13/100
# 100/100 [==============================] - 13s 125ms/step - loss: 0.5056 - accuracy: 0.7731 - val_loss: 0.5470 - val_accuracy: 0.7544
# Epoch 14/100
# 100/100 [==============================] - 12s 119ms/step - loss: 0.4873 - accuracy: 0.7725 - val_loss: 0.4831 - val_accuracy: 0.7806
# Epoch 15/100
# 100/100 [==============================] - 12s 120ms/step - loss: 0.4887 - accuracy: 0.7706 - val_loss: 0.5360 - val_accuracy: 0.7619
# Epoch 16/100
# 100/100 [==============================] - 12s 117ms/step - loss: 0.4756 - accuracy: 0.7853 - val_loss: 0.5016 - val_accuracy: 0.7594
