# %%
import matplotlib as plt

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(np.linspace(0, 1, 200))
y = np.log(x)
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16732/3684164614.py:4: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(np.linspace(0, 1, 200))
y = x * np.log(x)
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16732/826390810.py:4: RuntimeWarning: divide by zero encountered in log
#   y = x * np.log(x)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16732/826390810.py:4: RuntimeWarning: invalid value encountered in multiply
#   y = x * np.log(x)

# %%
count = 12500
accuracy = 0.9993
correct = count *accuracy
error = count * (1 - accuracy)
error * 45 / count
# Out:
# 0.03150000000000153

# %%
(error * 45) / count
# Out:
# 0.9000000000000009

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(np.linspace(0, 1, 200))
count = 12500
accuracy = 0.98
correct = count *accuracy
error = count * (1 - accuracy)
error * 45 / count
y = - (error * np.log(x) + correct * np.log(1- x)) / count
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16732/3935996840.py:9: RuntimeWarning: divide by zero encountered in log
#   y = - (error * np.log(x) + correct * np.log(1- x)) / count

# %%
x * math.log(x) + (1-x) math.log(1 - x)

x = 0 , pred = 0 , math.log(1-x)
x = 0 , pred = 1, math.log(x)
x = 1, pred = 1, math.log(1-x)
x = 1, pred = 0, math.log(x)
