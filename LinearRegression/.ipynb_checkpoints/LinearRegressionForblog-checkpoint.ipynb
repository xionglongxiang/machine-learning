# %%
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.arange(0,10,0.05).reshape(-1, 1)

# %%
# Out:
# array([[0.  ],
#        [0.05],
#        [0.1 ],
#        [0.15],
#        [0.2 ],
#        [0.25],
#        [0.3 ],
#        [0.35],
#        [0.4 ],
#        [0.45],
#        [0.5 ],
#        [0.55],
#        [0.6 ],
#        [0.65],
#        [0.7 ],
#        [0.75],
#        [0.8 ],
#        [0.85],
#        [0.9 ],
#        [0.95],
#        [1.  ],
#        [1.05],
#        [1.1 ],
#        [1.15],
#        [1.2 ],
#        [1.25],
#        [1.3 ],
#        [1.35],
#        [1.4 ],
#        [1.45],
#        [1.5 ],
#        [1.55],
#        [1.6 ],
#        [1.65],
#        [1.7 ],
#        [1.75],
#        [1.8 ],
#        [1.85],
#        [1.9 ],
#        [1.95],
#        [2.  ],
#        [2.05],
#        [2.1 ],
#        [2.15],
#        [2.2 ],
#        [2.25],
#        [2.3 ],
#        [2.35],
#        [2.4 ],
#        [2.45],
#        [2.5 ],
#        [2.55],
#        [2.6 ],
#        [2.65],
#        [2.7 ],
#        [2.75],
#        [2.8 ],
#        [2.85],
#        [2.9 ],
#        [2.95],
#        [3.  ],
#        [3.05],
#        [3.1 ],
#        [3.15],
#        [3.2 ],
#        [3.25],
#        [3.3 ],
#        [3.35],
#        [3.4 ],
#        [3.45],
#        [3.5 ],
#        [3.55],
#        [3.6 ],
#        [3.65],
#        [3.7 ],
#        [3.75],
#        [3.8 ],
#        [3.85],
#        [3.9 ],
#        [3.95],
#        [4.  ],
#        [4.05],
#        [4.1 ],
#        [4.15],
#        [4.2 ],
#        [4.25],
#        [4.3 ],
#        [4.35],
#        [4.4 ],
#        [4.45],
#        [4.5 ],
#        [4.55],
#        [4.6 ],
#        [4.65],
#        [4.7 ],
#        [4.75],
#        [4.8 ],
#        [4.85],
#        [4.9 ],
#        [4.95],
#        [5.  ],
#        [5.05],
#        [5.1 ],
#        [5.15],
#        [5.2 ],
#        [5.25],
#        [5.3 ],
#        [5.35],
#        [5.4 ],
#        [5.45],
#        [5.5 ],
#        [5.55],
#        [5.6 ],
#        [5.65],
#        [5.7 ],
#        [5.75],
#        [5.8 ],
#        [5.85],
#        [5.9 ],
#        [5.95],
#        [6.  ],
#        [6.05],
#        [6.1 ],
#        [6.15],
#        [6.2 ],
#        [6.25],
#        [6.3 ],
#        [6.35],
#        [6.4 ],
#        [6.45],
#        [6.5 ],
#        [6.55],
#        [6.6 ],
#        [6.65],
#        [6.7 ],
#        [6.75],
#        [6.8 ],
#        [6.85],
#        [6.9 ],
#        [6.95],
#        [7.  ],
#        [7.05],
#        [7.1 ],
#        [7.15],
#        [7.2 ],
#        [7.25],
#        [7.3 ],
#        [7.35],
#        [7.4 ],
#        [7.45],
#        [7.5 ],
#        [7.55],
#        [7.6 ],
#        [7.65],
#        [7.7 ],
#        [7.75],
#        [7.8 ],
#        [7.85],
#        [7.9 ],
#        [7.95],
#        [8.  ],
#        [8.05],
#        [8.1 ],
#        [8.15],
#        [8.2 ],
#        [8.25],
#        [8.3 ],
#        [8.35],
#        [8.4 ],
#        [8.45],
#        [8.5 ],
#        [8.55],
#        [8.6 ],
#        [8.65],
#        [8.7 ],
#        [8.75],
#        [8.8 ],
#        [8.85],
#        [8.9 ],
#        [8.95],
#        [9.  ],
#        [9.05],
#        [9.1 ],
#        [9.15],
#        [9.2 ],
#        [9.25],
#        [9.3 ],
#        [9.35],
#        [9.4 ],
#        [9.45],
#        [9.5 ],
#        [9.55],
#        [9.6 ],
#        [9.65],
#        [9.7 ],
#        [9.75],
#        [9.8 ],
#        [9.85],
#        [9.9 ],
#        [9.95]])

# %%
np.random.seed(100)
y = 0.5 * np.arange(0,10,0.05) + 3 + np.random.rand(len(X))

# %%
y
# Out:
# array([3.54340494, 3.30336939, 3.47451759, 3.91977613, 3.10471886,
#        3.24656912, 3.82074908, 4.00085276, 3.33670659, 3.80009333,
#        4.14132195, 3.48420212, 3.48532822, 3.43337689, 3.56969749,
#        4.35362378, 4.21168315, 3.59694101, 4.26622475, 3.74907375,
#        3.93170418, 4.46502982, 4.36764938, 3.91111195, 3.77541045,
#        3.99783205, 3.65568851, 3.92742635, 4.49566251, 3.74025497,
#        4.34884338, 4.37880454, 3.90514769, 4.20694344, 3.88647606,
#        4.76541156, 4.88092086, 3.98494199, 4.84054594, 4.5519015 ,
#        4.74247969, 4.65518394, 4.63184219, 4.09543913, 4.31002658,
#        4.66968488, 4.91911517, 4.42569523, 4.48589569, 5.07739509,
#        5.22500649, 5.15985329, 4.65950784, 4.92385895, 4.70479561,
#        4.71519022, 4.57808099, 4.66269421, 4.49486228, 4.98043143,
#        4.87625245, 5.1178054 , 5.17994188, 4.71760031, 5.5338413 ,
#        5.57137988, 5.25229666, 5.06276628, 5.063188  , 4.92934528,
#        5.02676506, 5.02153588, 4.973608  , 5.79160969, 5.8070126 ,
#        5.47297368, 5.63130075, 5.26538522, 5.0420556 , 5.43849802,
#        5.50869889, 5.11346017, 5.57803522, 6.06715804, 5.49503593,
#        5.46059644, 5.95545054, 5.92934899, 5.51306644, 5.85903668,
#        5.79040458, 5.57179375, 5.4107879 , 5.6376403 , 5.80697913,
#        6.03394007, 5.65425752, 6.06610126, 5.65012361, 6.13262481,
#        6.27828922, 6.3045984 , 6.16032815, 5.88400035, 6.29773491,
#        6.4846183 , 6.27532376, 6.65740783, 6.67650013, 5.89169413,
#        5.77317814, 5.93574455, 6.72349683, 6.77854985, 6.06097842,
#        6.23552525, 6.44937526, 6.19683085, 6.41060162, 6.67116156,
#        6.5003559 , 6.74107099, 6.57595594, 6.07639902, 6.49470029,
#        6.61716697, 6.55288033, 6.5292983 , 6.70061432, 6.67017663,
#        6.34043279, 6.54856292, 7.2434771 , 6.35154464, 6.38999869,
#        6.65814036, 6.98234417, 7.4158928 , 7.44264224, 7.46811737,
#        6.61004833, 7.18948145, 7.07398683, 6.74814991, 7.54296024,
#        6.86686009, 7.64893227, 7.25769382, 6.883279  , 7.11184542,
#        6.93967353, 7.18577067, 7.39468007, 7.54158609, 7.33689148,
#        7.18458982, 7.47744137, 7.36670782, 7.3096781 , 7.29633193,
#        7.20820724, 7.47625862, 7.54184291, 7.97407631, 7.82936046,
#        7.89508977, 7.52543925, 7.51873954, 7.85503521, 7.93603799,
#        7.36353758, 7.40802869, 7.75603906, 7.48473623, 8.3116419 ,
#        8.21261574, 7.92016069, 7.64327226, 7.58491872, 8.45407035,
#        8.2070435 , 8.38497556, 7.93717263, 7.82583402, 7.89943802,
#        8.48189553, 8.12298399, 8.33827705, 8.50572861, 7.9779805 ,
#        7.82957344, 8.50776061, 8.76139748, 8.77880473, 8.34049905,
#        8.50719206, 8.63299502, 8.8274095 , 8.11224692, 8.38088132])

# %%
plt.scatter(X.reshape(1, -1), y.reshape)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=0)

# %%
class LinearRegression:
    def __init__(self, eta=0.1, n_iters = 1e4, epsilon = 1e-8):
        
        self._X_train = None
        self._y_train = None
        self._theta = None
        self._eta = eta
        self._n_iters = n_iters
        self._epsilon = epsilon
        
    def Cost(self, theta, X_b, y):
        try:
            return np.sum(np.square(y - X_b.dot(theta))) / len(X_b)
        except:
            return float('inf')

    def dCost(self, theta, X_b, y):
        return (X_b.dot(theta) - y).dot(X_b) * 2 / len(X_b)

    def gradient_descent(self, X_b, y):
        theta = self._initial_theta
        eta = self._eta
        n_iters = self._n_iters
        epsilon = self._epsilon
        
        i_iter = 0

        while i_iter < n_iters:
            gradient = dJ(theta, X_b, y)
            last_theta = theta
            theta = theta - eta * gradient

            if (abs(J(theta, X_b, y) - J(last_theta, X_b, y)) < epsilon):
                break
            i_iter += 1
        return theta
    def fit(self, X_train, y_train):
        print(X_train, y_train)
        assert X_train.shape[1] == y_train.shape[0], 'train data has wrong dimenssion'
        self._X_train = X_train
        self._y_train = y_train
        
        X_b = np.hstack([np.ones((len(_X_train), 1)), _X_train])
        initial_theta = np.zeros(X_b.shape[1])
        eta = 0.01


        self.gradient_descent(X_b, y_train, init_theta, eta, n_iters, epsilon)
        
        return self
    
    def predict(self, X_test, y_test):
        return self

# %%
linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
# Out:
# [6.55 4.8  9.05 0.95 7.65 4.6  2.7  8.15 2.55 4.3  6.95 4.5  6.85 5.05
#  7.2  4.45 5.45 0.7  1.35 7.05 9.35 2.3  6.9  9.75 5.4  3.1  0.1  2.95
#  6.8  9.85 2.15 0.5  9.7  3.65 9.8  8.9  8.75 6.3  4.65 5.6  7.9  9.55
#  2.5  0.   4.7  5.5  4.75 3.2  8.35 2.05 3.45 2.45 2.4  4.25 0.65 8.05
#  1.15 9.3  6.75 1.   0.75 3.9  5.2  2.6  5.   3.8  0.15 5.8  8.2  9.9
#  0.3  3.4  4.2  6.05 7.75 8.55 7.8  4.55 9.95 0.55 5.95 5.1  1.75 2.85
#  3.25 0.05 6.   8.1  2.1  5.25 6.6  8.65 0.85 1.9  6.65 2.65 7.85 6.4
#  1.7  1.4  5.7  7.55 1.55 8.3  6.35 8.8  1.6  7.1  8.45 7.35 1.45 4.95
#  4.1  3.95 5.75 7.4  9.65 3.6  3.85 1.25 8.25 4.05 9.4  8.7  9.5  1.95
#  2.9  7.   4.4  3.5  4.35 1.8  1.05 0.45 5.15 3.35 9.6  5.85 2.35 8.6 ] [6.54856292 5.65425752 8.38497556 3.74907375 7.54158609 5.4107879
#  4.70479561 7.97407631 5.15985329 5.95545054 7.46811737 5.79040458
#  7.4158928  6.3045984  7.54296024 5.85903668 5.89169413 3.56969749
#  3.92742635 7.18948145 8.33827705 4.91911517 7.44264224 8.50719206
#  6.67650013 5.17994188 3.47451759 4.98043143 6.98234417 8.8274095
#  4.09543913 4.14132195 8.34049905 5.79160969 8.63299502 7.58491872
#  8.21261574 6.55288033 5.6376403  6.72349683 7.3096781  8.50776061
#  5.22500649 3.54340494 5.80697913 5.77317814 6.03394007 5.5338413
#  7.51873954 4.65518394 4.92934528 5.07739509 4.48589569 5.46059644
#  3.43337689 7.47625862 3.91111195 8.12298399 6.65814036 3.93170418
#  4.35362378 5.0420556  6.29773491 4.65950784 6.27828922 5.63130075
#  3.91977613 6.44937526 7.82936046 8.11224692 3.82074908 5.063188
#  5.49503593 6.74107099 7.18458982 7.40802869 7.47744137 5.57179375
#  8.38088132 3.48420212 6.67116156 6.16032815 4.76541156 4.66269421
#  5.57137988 3.30336939 6.5003559  7.54184291 4.63184219 6.4846183
#  7.2434771  7.48473623 3.59694101 4.84054594 6.35154464 4.92385895
#  7.36670782 6.70061432 3.88647606 4.49566251 6.06097842 7.18577067
#  4.37880454 7.52543925 6.5292983  7.92016069 3.90514769 7.07398683
#  7.93603799 7.25769382 3.74025497 6.13262481 5.57803522 5.43849802
#  6.23552525 6.883279   8.77880473 4.973608   5.26538522 3.99783205
#  7.89508977 5.11346017 8.50572861 8.3116419  7.82957344 4.5519015
#  4.49486228 6.61004833 5.51306644 5.02676506 5.92934899 4.88092086
#  4.46502982 3.80009333 5.88400035 5.06276628 8.76139748 6.19683085
#  4.42569523 7.75603906]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-475f11aef40b> in <module>
#       1 linear_regression = LinearRegression()
# ----> 2 linear_regression.fit(X_train, y_train)
#
# <ipython-input-52-234fda0ed4f9> in fit(self, X_train, y_train)
#      37     def fit(self, X_train, y_train):
#      38         print(X_train, y_train)
# ---> 39         assert X_train.shape[1] == y_train.shape[0], 'train data has wrong dimenssion'
#      40         self._X_train = X_train
#      41         self._y_train = y_train
#
# IndexError: tuple index out of range

# %%
X_b = np.zeros(3)
X_b[0] = 1

# %%
X_b
# Out:
# array([1., 0., 0.])

# %%
np.ones((3,1))
# Out:
# array([[1.],
#        [1.],
#        [1.]])
